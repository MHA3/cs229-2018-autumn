# %% [markdown]
# # (c)

# %%
import p05_percept

# %%
p05_percept.main()

# %% [markdown]
# The dot kernel fails because it doesn't actually increase the dimensionality of the points which are linearly inseparable in the existing hyperplane.
